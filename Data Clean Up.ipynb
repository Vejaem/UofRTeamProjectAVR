# %%
import pandas as pd 
import numpy as np

# %%
unemploy_file = pd.read_csv('Data/Unemployment Data.csv')
unemploy_file.head()
# Out:
#   States and selected areas:  Employment status of the civilian noninstitutional population,  \
# 0      January 1976 to date, not seasonally adjusted
# 1                                                NaN
# 2                                          FIPS Code
# 3                                                NaN
# 4                                                NaN
#
#        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0             NaN        NaN        NaN
# 1             NaN        NaN        NaN
# 2  State and area     Period        NaN
# 3             NaN        NaN        NaN
# 4             NaN       Year      Month
#
#                               Unnamed: 4            Unnamed: 5  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2  Civilian non-institutional population  Civilian labor force
# 3                                    NaN                 Total
# ...

# %%
unemploy_file = unemploy_file.drop([0,1,2,3,4,6])
unemploy_file.head()
# Out:
#    States and selected areas:  Employment status of the civilian noninstitutional population,  \
# 5                                                 NaN
# 7                                                  01
# 8                                                  02
# 9                                                  04
# 10                                                 05
#
#    Unnamed: 1   Unnamed: 2   Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 5         NaN  Labor force  Labor force           NaN           NaN
# 7     Alabama         1976           01  2,605,000     1,479,554
# 8      Alaska         1976           01    232,000       153,109
# 9     Arizona         1976           01  1,621,000       959,530
# 10   Arkansas         1976           01  1,536,000       857,544
#
#    Unnamed: 6    Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10
# 5         NaN   Labor force        NaN       level        rate
# 7     56.8     1,362,852       52.3     116,702         7.9
# ...

# %%
unemploy_file = unemploy_file.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
                                 'Unnamed: 9'], axis=1)
unemploy_file.head()
# Out:
#    States and selected areas:  Employment status of the civilian noninstitutional population,  \
# 5                                                 NaN
# 7                                                  01
# 8                                                  02
# 9                                                  04
# 10                                                 05
#
#    Unnamed: 1   Unnamed: 2   Unnamed: 3 Unnamed: 10
# 5         NaN  Labor force  Labor force        rate
# 7     Alabama         1976           01      7.9
# 8      Alaska         1976           01      9.3
# 9     Arizona         1976           01     11.7
# 10   Arkansas         1976           01      8.9

# %%
unemploy_file = unemploy_file.drop([5])
unemploy_file.head()
# Out:
#    States and selected areas:  Employment status of the civilian noninstitutional population,  \
# 7                                                  01
# 8                                                  02
# 9                                                  04
# 10                                                 05
# 11                                                 06
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 10
# 7      Alabama       1976         01      7.9
# 8       Alaska       1976         01      9.3
# 9      Arizona       1976         01     11.7
# 10    Arkansas       1976         01      8.9
# 11  California       1976         01     10.3

# %%
unemploy_file = unemploy_file.rename({'Unnamed: 1':'State', 'Unnamed: 2':'Year', 'Unnamed: 3': 'Month', 'Unnamed: 10':'Unemployment Rate'}, axis=1)
unemploy_file.head()
# Out:
#    States and selected areas:  Employment status of the civilian noninstitutional population,  \
# 7                                                  01
# 8                                                  02
# 9                                                  04
# 10                                                 05
# 11                                                 06
#
#          State  Year Month Unemployment Rate
# 7      Alabama  1976    01            7.9
# 8       Alaska  1976    01            9.3
# 9      Arizona  1976    01           11.7
# 10    Arkansas  1976    01            8.9
# 11  California  1976    01           10.3
